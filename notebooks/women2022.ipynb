# %%
import sys
import os

# Get the current working directory
current_dir = os.getcwd()

# Add the parent directory to the sys.path
sys.path.append(os.path.dirname(current_dir))

from scripts import dataClean
from scripts import priorPlaceGraph
from scripts import conferncePlaceGraph
from scripts import regionPlaceGraph
from scripts import athletesByRegion
from scripts import distributionByRegion
from scripts import changeInPlacement

# %%
#Comparision year to year prior 
df = dataClean.dataClean('/Users/lukelambert/Desktop/NCAA_XC.xlsx', 'Women 2022')
year = 2022
priorPlaceGraph.graph(df, year)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 #Comparision year to year prior
# ----> 2 df = dataClean.dataClean('/Users/lukelambert/Desktop/NCAA_XC.xlsx', 'Women 2022')
#       3 year = 2022
#       4 priorPlaceGraph.graph(df, year)
#
# File ~/Documents/GitHub/ncaaProject/scripts/dataClean.py:19, in dataClean(path, sheet)
#      16         return np.nan
#      17     return int(''.join(filter(str.isdigit, ordinal_str)))
# ---> 19 df['conferencePlace'] = df['conferencePlace'].apply(ordinal_to_int)
#      20 df['regionPlace'] = df['regionPlace'].apply(ordinal_to_int)
#      21 df['ncaaPriorPlace'] = df['ncaaPriorPlace'].apply(ordinal_to_int)
#
# File ~/Documents/GitHub/ncaaProject/venv/lib/python3.11/site-packages/pandas/core/series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
# ...

# %%
conferncePlaceGraph.graph(df, year)
# Out:
# Linear Regression R-squared: 0.3323
# Quadratic Regression R-squared: 0.3561

# %%
regionPlaceGraph.graph(df, year)
# Out:
# Linear Regression R-squared: 0.2293
# Quadratic Regression R-squared: 0.2626

# %%
athletesByRegion.graph(df, year)

# %%
distributionByRegion.graph(df, year)

# %%
changeInPlacement.graph(df, year)
# Out:
# 125.0
